# %%
import sys
import os
sys.path.append(os.path.abspath(".."))  # adds the project root to the path

from scripts.data_fetch import get_gw_status, get_gw_finished_status, get_league_id, get_gw_points

# %%
gw_no = 38

# %%
get_gw_status()
# Out:
# [{'id': 1,
#   'name': 'Gameweek 1',
#   'deadline_time': '2024-08-16T17:30:00Z',
#   'release_time': None,
#   'average_entry_score': 57,
#   'finished': True,
#   'data_checked': True,
#   'highest_scoring_entry': 3546234,
#   'deadline_time_epoch': 1723829400,
#   'deadline_time_game_offset': 0,
#   'highest_score': 127,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': False,
#   'h2h_ko_matches_created': False,
#   'can_enter': False,
#   'can_manage': False,
#   'released': True,
#   'ranked_count': 8597356,
#   'overrides': {'rules': {},
#    'scoring': {},
#    'element_types': [],
#    'pick_multiplier': None},
#   'chip_plays': [{'chip_name': 'bboost', 'num_played': 144974},
#    {'chip_name': '3xc', 'num_played': 221430}],
#   'most_selected': 401,
#   'most_transferred_in': 27,
#   'top_element': 328,
#   'top_element_info': {'id': 328, 'points': 14},
#   'transfers_made': 0,
#   'most_captained': 351,
#   'most_vice_captained': 351},
#  {'id': 2,
#   'name': 'Gameweek 2',
#   'deadline_time': '2024-08-24T10:00:00Z',
#   'release_time': None,
#   'average_entry_score': 69,
#   'finished': True,
#   'data_checked': True,
#   'highest_scoring_entry': 9442126,
#   'deadline_time_epoch': 1724493600,
#   'deadline_time_game_offset': 0,
#   'highest_score': 154,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': True,
#   'h2h_ko_matches_created': True,
#   'can_enter': False,
#   'can_manage': False,
#   'released': True,
#   'ranked_count': 9543353,
#   'overrides': {'rules': {},
#    'scoring': {},
#    'element_types': [],
#    'pick_multiplier': None},
#   'chip_plays': [{'chip_name': 'bboost', 'num_played': 118782},
#    {'chip_name': 'freehit', 'num_played': 102788},
#    {'chip_name': 'wildcard', 'num_played': 217521},
#    {'chip_name': '3xc', 'num_played': 612384}],
#   'most_selected': 401,
#   'most_transferred_in': 594,
#   'top_element': 177,
#   'top_element_info': {'id': 177, 'points': 20},
#   'transfers_made': 13364453,
#   'most_captained': 351,
#   'most_vice_captained': 401},
#  {'id': 3,
#   'name': 'Gameweek 3',
#   'deadline_time': '2024-08-31T10:00:00Z',
#   'release_time': None,
#   'average_entry_score': 64,
#   'finished': True,
#   'data_checked': True,
#   'highest_scoring_entry': 430195,
#   'deadline_time_epoch': 1725098400,
#   'deadline_time_game_offset': 0,
#   'highest_score': 130,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': True,
#   'h2h_ko_matches_created': True,
#   'can_enter': False,
#   'can_manage': False,
#   'released': True,
#   'ranked_count': 9912161,
#   'overrides': {'rules': {},
#    'scoring': {},
#    'element_types': [],
#    'pick_multiplier': None},
#   'chip_plays': [{'chip_name': 'bboost', 'num_played': 87334},
#    {'chip_name': 'freehit', 'num_played': 140192},
#    {'chip_name': 'wildcard', 'num_played': 656652},
#    {'chip_name': '3xc', 'num_played': 186907}],
#   'most_selected': 351,
#   'most_transferred_in': 177,
#   'top_element': 328,
#   'top_element_info': {'id': 328, 'points': 17},
#   'transfers_made': 23723836,
#   'most_captained': 351,
#   'most_vice_captained': 328},
#  {'id': 4,
#   'name': 'Gameweek 4',
#   'deadline_time': '2024-09-14T10:00:00Z',
#   'release_time': None,
#   'average_entry_score': 51,
#   'finished': True,
#   'data_checked': True,
#   'highest_scoring_entry': 3560750,
#   'deadline_time_epoch': 1726308000,
#   'deadline_time_game_offset': 0,
#   'highest_score': 120,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': True,
#   'h2h_ko_matches_created': True,
#   'can_enter': False,
#   'can_manage': False,
#   'released': True,
#   'ranked_count': 10178753,
#   'overrides': {'rules': {},
#    'scoring': {},
#    'element_types': [],
#    'pick_multiplier': None},
#   'chip_plays': [{'chip_name': 'bboost', 'num_played': 83637},
#    {'chip_name': 'freehit', 'num_played': 125561},
#    {'chip_name': 'wildcard', 'num_played': 940783},
#    {'chip_name': '3xc', 'num_played': 199688}],
#   'most_selected': 351,
#   'most_transferred_in': 129,
#   'top_element': 185,
#   'top_element_info': {'id': 185, 'points': 15},
#   'transfers_made': 25930392,
#   'most_captained': 351,
#   'most_vice_captained': 328},
#  {'id': 5,
#   'name': 'Gameweek 5',
#   'deadline_time': '2024-09-21T10:00:00Z',
#   'release_time': None,
#   'average_entry_score': 58,
#   'finished': True,
#   'data_checked': True,
#   'highest_scoring_entry': 1773336,
#   'deadline_time_epoch': 1726912800,
#   'deadline_time_game_offset': 0,
#   'highest_score': 131,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': True,
#   'h2h_ko_matches_created': True,
#   'can_enter': False,
#   'can_manage': False,
#   'released': True,
#   'ranked_count': 10279610,
#   'overrides': {'rules': {},
#    'scoring': {},
#    'element_types': [],
#    'pick_multiplier': None},
#   'chip_plays': [{'chip_name': 'bboost', 'num_played': 66447},
#    {'chip_name': 'freehit', 'num_played': 79498},
#    {'chip_name': 'wildcard', 'num_played': 311710},
#    {'chip_name': '3xc', 'num_played': 71288}],
#   'most_selected': 351,
#   'most_transferred_in': 58,
#   'top_element': 180,
#   'top_element_info': {'id': 180, 'points': 16},
#   'transfers_made': 13036058,
#   'most_captained': 351,
#   'most_vice_captained': 351},
#  {'id': 6,
#   'name': 'Gameweek 6',
#   'deadline_time': '2024-09-28T10:00:00Z',
#   'release_time': None,
#   'average_entry_score': 50,
#   'finished': True,
#   'data_checked': True,
#   'highest_scoring_entry': 7479996,
#   'deadline_time_epoch': 1727517600,
#   'deadline_time_game_offset': 0,
#   'highest_score': 142,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': True,
#   'h2h_ko_matches_created': True,
#   'can_enter': False,
#   'can_manage': False,
#   'released': True,
#   'ranked_count': 10369689,
#   'overrides': {'rules': {},
#    'scoring': {},
#    'element_types': [],
#    'pick_multiplier': None},
#   'chip_plays': [{'chip_name': 'bboost', 'num_played': 62665},
#    {'chip_name': 'freehit', 'num_played': 84229},
#    {'chip_name': 'wildcard', 'num_played': 663489},
#    {'chip_name': '3xc', 'num_played': 83406}],
#   'most_selected': 351,
#   'most_transferred_in': 327,
#   'top_element': 182,
#   'top_element_info': {'id': 182, 'points': 25},
#   'transfers_made': 21036913,
#   'most_captained': 351,
#   'most_vice_captained': 328},
#  {'id': 7,
#   'name': 'Gameweek 7',
#   'deadline_time': '2024-10-05T10:00:00Z',
#   'release_time': None,
#   'average_entry_score': 46,
#   'finished': True,
#   'data_checked': True,
#   'highest_scoring_entry': 759474,
#   'deadline_time_epoch': 1728122400,
#   'deadline_time_game_offset': 0,
#   'highest_score': 130,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': True,
#   'h2h_ko_matches_created': True,
#   'can_enter': False,
#   'can_manage': False,
#   'released': True,
#   'ranked_count': 10466714,
#   'overrides': {'rules': {},
#    'scoring': {},
#    'element_types': [],
#    'pick_multiplier': None},
#   'chip_plays': [{'chip_name': 'bboost', 'num_played': 54778},
#    {'chip_name': 'freehit', 'num_played': 81146},
#    {'chip_name': 'wildcard', 'num_played': 308835},
#    {'chip_name': '3xc', 'num_played': 140205}],
#   'most_selected': 351,
#   'most_transferred_in': 182,
#   'top_element': 512,
#   'top_element_info': {'id': 512, 'points': 18},
#   'transfers_made': 14594461,
#   'most_captained': 351,
#   'most_vice_captained': 328},
#  {'id': 8,
#   'name': 'Gameweek 8',
#   'deadline_time': '2024-10-19T10:00:00Z',
#   'release_time': None,
#   'average_entry_score': 36,
#   'finished': True,
#   'data_checked': True,
#   'highest_scoring_entry': 5482232,
#   'deadline_time_epoch': 1729332000,
#   'deadline_time_game_offset': 0,
#   'highest_score': 98,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': True,
#   'h2h_ko_matches_created': True,
#   'can_enter': False,
#   'can_manage': False,
#   'released': True,
#   'ranked_count': 10552679,
#   'overrides': {'rules': {},
#    'scoring': {},
#    'element_types': [],
#    'pick_multiplier': None},
#   'chip_plays': [{'chip_name': 'bboost', 'num_played': 65446},
#    {'chip_name': 'freehit', 'num_played': 64301},
#    {'chip_name': 'wildcard', 'num_played': 221063},
#    {'chip_name': '3xc', 'num_played': 111602}],
#   'most_selected': 351,
#   'most_transferred_in': 491,
#   'top_element': 228,
#   'top_element_info': {'id': 228, 'points': 14},
#   'transfers_made': 11911632,
#   'most_captained': 351,
#   'most_vice_captained': 328},
#  {'id': 9,
#   'name': 'Gameweek 9',
#   'deadline_time': '2024-10-25T17:30:00Z',
#   'release_time': None,
#   'average_entry_score': 54,
#   'finished': True,
#   'data_checked': True,
#   'highest_scoring_entry': 2039494,
#   'deadline_time_epoch': 1729877400,
#   'deadline_time_game_offset': 0,
#   'highest_score': 117,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': True,
#   'h2h_ko_matches_created': True,
#   'can_enter': False,
#   'can_manage': False,
#   'released': True,
#   'ranked_count': 10594653,
#   'overrides': {'rules': {},
#    'scoring': {},
#    'element_types': [],
#    'pick_multiplier': None},
#   'chip_plays': [{'chip_name': 'bboost', 'num_played': 51136},
#    {'chip_name': 'freehit', 'num_played': 71811},
#    {'chip_name': 'wildcard', 'num_played': 158486},
#    {'chip_name': '3xc', 'num_played': 330035}],
#   'most_selected': 351,
#   'most_transferred_in': 99,
#   'top_element': 99,
#   'top_element_info': {'id': 99, 'points': 15},
#   'transfers_made': 10882045,
#   'most_captained': 351,
#   'most_vice_captained': 182},
#  {'id': 10,
#   'name': 'Gameweek 10',
#   'deadline_time': '2024-11-02T11:00:00Z',
#   'release_time': None,
#   'average_entry_score': 39,
#   'finished': True,
#   'data_checked': True,
#   'highest_scoring_entry': 1689659,
#   'deadline_time_epoch': 1730545200,
#   'deadline_time_game_offset': 0,
#   'highest_score': 111,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': True,
#   'h2h_ko_matches_created': True,
#   'can_enter': False,
#   'can_manage': False,
#   'released': True,
#   'ranked_count': 10648436,
#   'overrides': {'rules': {},
#    'scoring': {},
#    'element_types': [],
#    'pick_multiplier': None},
#   'chip_plays': [{'chip_name': 'bboost', 'num_played': 75823},
#    {'chip_name': 'freehit', 'num_played': 70729},
#    {'chip_name': 'wildcard', 'num_played': 162964},
#    {'chip_name': '3xc', 'num_played': 85359}],
#   'most_selected': 351,
#   'most_transferred_in': 99,
#   'top_element': 82,
#   'top_element_info': {'id': 82, 'points': 16},
#   'transfers_made': 11763382,
#   'most_captained': 351,
#   'most_vice_captained': 182},
#  {'id': 11,
#   'name': 'Gameweek 11',
#   'deadline_time': '2024-11-09T13:30:00Z',
#   'release_time': None,
#   'average_entry_score': 49,
#   'finished': True,
#   'data_checked': True,
#   'highest_scoring_entry': 10668888,
#   'deadline_time_epoch': 1731159000,
#   'deadline_time_game_offset': 0,
#   'highest_score': 136,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': True,
#   'h2h_ko_matches_created': True,
#   'can_enter': False,
#   'can_manage': False,
#   'released': True,
#   'ranked_count': 10693676,
#   'overrides': {'rules': {},
#    'scoring': {},
#    'element_types': [],
#    'pick_multiplier': None},
#   'chip_plays': [{'chip_name': 'bboost', 'num_played': 79875},
#    {'chip_name': 'freehit', 'num_played': 84689},
#    {'chip_name': 'wildcard', 'num_played': 138253},
#    {'chip_name': '3xc', 'num_played': 52784}],
#   'most_selected': 351,
#   'most_transferred_in': 447,
#   'top_element': 366,
#   'top_element_info': {'id': 366, 'points': 17},
#   'transfers_made': 11631910,
#   'most_captained': 351,
#   'most_vice_captained': 328},
#  {'id': 12,
#   'name': 'Gameweek 12',
#   'deadline_time': '2024-11-23T11:00:00Z',
#   'release_time': None,
#   'average_entry_score': 49,
#   'finished': True,
#   'data_checked': True,
#   'highest_scoring_entry': 7440806,
#   'deadline_time_epoch': 1732359600,
#   'deadline_time_game_offset': 0,
#   'highest_score': 128,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': True,
#   'h2h_ko_matches_created': True,
#   'can_enter': False,
#   'can_manage': False,
#   'released': True,
#   'ranked_count': 10751495,
#   'overrides': {'rules': {},
#    'scoring': {},
#    'element_types': [],
#    'pick_multiplier': None},
#   'chip_plays': [{'chip_name': 'bboost', 'num_played': 59590},
#    {'chip_name': 'freehit', 'num_played': 89443},
#    {'chip_name': 'wildcard', 'num_played': 252772},
#    {'chip_name': '3xc', 'num_played': 111773}],
#   'most_selected': 351,
#   'most_transferred_in': 366,
#   'top_element': 541,
#   'top_element_info': {'id': 541, 'points': 16},
#   'transfers_made': 13315756,
#   'most_captained': 351,
#   'most_vice_captained': 182},
#  {'id': 13,
#   'name': 'Gameweek 13',
#   'deadline_time': '2024-11-29T18:30:00Z',
#   'release_time': None,
#   'average_entry_score': 60,
#   'finished': True,
#   'data_checked': True,
#   'highest_scoring_entry': 1929511,
#   'deadline_time_epoch': 1732905000,
#   'deadline_time_game_offset': 0,
#   'highest_score': 144,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': True,
#   'h2h_ko_matches_created': True,
#   'can_enter': False,
#   'can_manage': False,
#   'released': True,
#   'ranked_count': 10786063,
#   'overrides': {'rules': {},
#    'scoring': {},
#    'element_types': [],
#    'pick_multiplier': None},
#   'chip_plays': [{'chip_name': 'bboost', 'num_played': 57138},
#    {'chip_name': 'freehit', 'num_played': 71881},
#    {'chip_name': 'wildcard', 'num_played': 144095},
#    {'chip_name': '3xc', 'num_played': 44722}],
#   'most_selected': 328,
#   'most_transferred_in': 541,
#   'top_element': 106,
#   'top_element_info': {'id': 106, 'points': 23},
#   'transfers_made': 10651205,
#   'most_captained': 328,
#   'most_vice_captained': 182},
#  {'id': 14,
#   'name': 'Gameweek 14',
#   'deadline_time': '2024-12-03T18:00:00Z',
#   'release_time': None,
#   'average_entry_score': 58,
#   'finished': True,
#   'data_checked': True,
#   'highest_scoring_entry': 2964307,
#   'deadline_time_epoch': 1733248800,
#   'deadline_time_game_offset': 0,
#   'highest_score': 132,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': True,
#   'h2h_ko_matches_created': True,
#   'can_enter': False,
#   'can_manage': False,
#   'released': True,
#   'ranked_count': 10821193,
#   'overrides': {'rules': {},
#    'scoring': {},
#    'element_types': [],
#    'pick_multiplier': None},
#   'chip_plays': [{'chip_name': 'bboost', 'num_played': 58057},
#    {'chip_name': 'freehit', 'num_played': 60749},
#    {'chip_name': 'wildcard', 'num_played': 141083},
#    {'chip_name': '3xc', 'num_played': 80792}],
#   'most_selected': 328,
#   'most_transferred_in': 180,
#   'top_element': 328,
#   'top_element_info': {'id': 328, 'points': 18},
#   'transfers_made': 10912413,
#   'most_captained': 351,
#   'most_vice_captained': 328},
#  {'id': 15,
#   'name': 'Gameweek 15',
#   'deadline_time': '2024-12-07T11:00:00Z',
#   'release_time': None,
#   'average_entry_score': 50,
#   'finished': True,
#   'data_checked': True,
#   'highest_scoring_entry': 7399737,
#   'deadline_time_epoch': 1733569200,
#   'deadline_time_game_offset': 0,
#   'highest_score': 119,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': True,
#   'h2h_ko_matches_created': True,
#   'can_enter': False,
#   'can_manage': False,
#   'released': True,
#   'ranked_count': 10854873,
#   'overrides': {'rules': {},
#    'scoring': {},
#    'element_types': [],
#    'pick_multiplier': None},
#   'chip_plays': [{'chip_name': 'bboost', 'num_played': 46111},
#    {'chip_name': 'freehit', 'num_played': 102956},
#    {'chip_name': 'wildcard', 'num_played': 98439},
#    {'chip_name': '3xc', 'num_played': 72929}],
#   'most_selected': 182,
#   'most_transferred_in': 17,
#   'top_element': 182,
#   'top_element_info': {'id': 182, 'points': 18},
#   'transfers_made': 10409133,
#   'most_captained': 328,
#   'most_vice_captained': 182},
#  {'id': 16,
#   'name': 'Gameweek 16',
#   'deadline_time': '2024-12-14T13:30:00Z',
#   'release_time': None,
#   'average_entry_score': 47,
#   'finished': True,
#   'data_checked': True,
#   'highest_scoring_entry': 5142221,
#   'deadline_time_epoch': 1734183000,
#   'deadline_time_game_offset': 0,
#   'highest_score': 119,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': True,
#   'h2h_ko_matches_created': True,
#   'can_enter': False,
#   'can_manage': False,
#   'released': True,
#   'ranked_count': 10906389,
#   'overrides': {'rules': {},
#    'scoring': {},
#    'element_types': [],
#    'pick_multiplier': None},
#   'chip_plays': [{'chip_name': 'bboost', 'num_played': 72296},
#    {'chip_name': 'freehit', 'num_played': 56121},
#    {'chip_name': 'wildcard', 'num_played': 120570},
#    {'chip_name': '3xc', 'num_played': 100883}],
#   'most_selected': 328,
#   'most_transferred_in': 401,
#   'top_element': 585,
#   'top_element_info': {'id': 585, 'points': 17},
#   'transfers_made': 10586275,
#   'most_captained': 328,
#   'most_vice_captained': 182},
#  {'id': 17,
#   'name': 'Gameweek 17',
#   'deadline_time': '2024-12-21T11:00:00Z',
#   'release_time': None,
#   'average_entry_score': 60,
#   'finished': True,
#   'data_checked': True,
#   'highest_scoring_entry': 4917384,
#   'deadline_time_epoch': 1734778800,
#   'deadline_time_game_offset': 0,
#   'highest_score': 151,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': True,
#   'h2h_ko_matches_created': True,
#   'can_enter': False,
#   'can_manage': False,
#   'released': True,
#   'ranked_count': 10946145,
#   'overrides': {'rules': {},
#    'scoring': {},
#    'element_types': [],
#    'pick_multiplier': None},
#   'chip_plays': [{'chip_name': 'bboost', 'num_played': 80801},
#    {'chip_name': 'freehit', 'num_played': 59644},
#    {'chip_name': 'wildcard', 'num_played': 136974},
#    {'chip_name': '3xc', 'num_played': 55811}],
#   'most_selected': 182,
#   'most_transferred_in': 364,
#   'top_element': 328,
#   'top_element_info': {'id': 328, 'points': 21},
#   'transfers_made': 10405730,
#   'most_captained': 328,
#   'most_vice_captained': 182},
#  {'id': 18,
#   'name': 'Gameweek 18',
#   'deadline_time': '2024-12-26T11:00:00Z',
#   'release_time': None,
#   'average_entry_score': 51,
#   'finished': True,
#   'data_checked': True,
#   'highest_scoring_entry': 2701866,
#   'deadline_time_epoch': 1735210800,
#   'deadline_time_game_offset': 0,
#   'highest_score': 118,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': True,
#   'h2h_ko_matches_created': True,
#   'can_enter': False,
#   'can_manage': False,
#   'released': True,
#   'ranked_count': 10984600,
#   'overrides': {'rules': {},
#    'scoring': {},
#    'element_types': [],
#    'pick_multiplier': None},
#   'chip_plays': [{'chip_name': 'bboost', 'num_played': 97727},
#    {'chip_name': 'freehit', 'num_played': 83399},
#    {'chip_name': 'wildcard', 'num_played': 374001},
#    {'chip_name': '3xc', 'num_played': 202796}],
#   'most_selected': 328,
#   'most_transferred_in': 401,
#   'top_element': 403,
#   'top_element_info': {'id': 403, 'points': 13},
#   'transfers_made': 13895381,
#   'most_captained': 328,
#   'most_vice_captained': 182},
#  {'id': 19,
#   'name': 'Gameweek 19',
#   'deadline_time': '2024-12-29T13:00:00Z',
#   'release_time': None,
#   'average_entry_score': 66,
#   'finished': True,
#   'data_checked': True,
#   'highest_scoring_entry': 3191421,
#   'deadline_time_epoch': 1735477200,
#   'deadline_time_game_offset': 0,
#   'highest_score': 142,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': True,
#   'h2h_ko_matches_created': True,
#   'can_enter': False,
#   'can_manage': False,
#   'released': True,
#   'ranked_count': 11011909,
#   'overrides': {'rules': {},
#    'scoring': {},
#    'element_types': [],
#    'pick_multiplier': None},
#   'chip_plays': [{'chip_name': 'bboost', 'num_played': 83841},
#    {'chip_name': 'freehit', 'num_played': 62471},
#    {'chip_name': 'wildcard', 'num_played': 427439},
#    {'chip_name': '3xc', 'num_played': 67924}],
#   'most_selected': 182,
#   'most_transferred_in': 401,
#   'top_element': 328,
#   'top_element_info': {'id': 328, 'points': 16},
#   'transfers_made': 10957444,
#   'most_captained': 328,
#   'most_vice_captained': 182},
#  {'id': 20,
#   'name': 'Gameweek 20',
#   'deadline_time': '2025-01-04T11:00:00Z',
#   'release_time': None,
#   'average_entry_score': 60,
#   'finished': True,
#   'data_checked': True,
#   'highest_scoring_entry': 1247541,
#   'deadline_time_epoch': 1735988400,
#   'deadline_time_game_offset': 0,
#   'highest_score': 136,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': True,
#   'h2h_ko_matches_created': True,
#   'can_enter': False,
#   'can_manage': False,
#   'released': True,
#   'ranked_count': 11058766,
#   'overrides': {'rules': {},
#    'scoring': {},
#    'element_types': [],
#    'pick_multiplier': None},
#   'chip_plays': [{'chip_name': 'bboost', 'num_played': 73435},
#    {'chip_name': 'freehit', 'num_played': 67748},
#    {'chip_name': 'wildcard', 'num_played': 412768},
#    {'chip_name': '3xc', 'num_played': 141464}],
#   'most_selected': 328,
#   'most_transferred_in': 447,
#   'top_element': 99,
#   'top_element_info': {'id': 99, 'points': 19},
#   'transfers_made': 13978697,
#   'most_captained': 328,
#   'most_vice_captained': 182},
#  {'id': 21,
#   'name': 'Gameweek 21',
#   'deadline_time': '2025-01-14T18:00:00Z',
#   'release_time': None,
#   'average_entry_score': 55,
#   'finished': True,
#   'data_checked': True,
#   'highest_scoring_entry': 434390,
#   'deadline_time_epoch': 1736877600,
#   'deadline_time_game_offset': 0,
#   'highest_score': 148,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': True,
#   'h2h_ko_matches_created': True,
#   'can_enter': False,
#   'can_manage': False,
#   'released': True,
#   'ranked_count': 11114287,
#   'overrides': {'rules': {},
#    'scoring': {},
#    'element_types': [],
#    'pick_multiplier': None},
#   'chip_plays': [{'chip_name': 'bboost', 'num_played': 89332},
#    {'chip_name': 'freehit', 'num_played': 63224},
#    {'chip_name': 'wildcard', 'num_played': 286969},
#    {'chip_name': '3xc', 'num_played': 51092}],
#   'most_selected': 328,
#   'most_transferred_in': 398,
#   'top_element': 364,
#   'top_element_info': {'id': 364, 'points': 20},
#   'transfers_made': 11543203,
#   'most_captained': 328,
#   'most_vice_captained': 182},
#  {'id': 22,
#   'name': 'Gameweek 22',
#   'deadline_time': '2025-01-18T11:00:00Z',
#   'release_time': None,
#   'average_entry_score': 46,
#   'finished': True,
#   'data_checked': True,
#   'highest_scoring_entry': 2700271,
#   'deadline_time_epoch': 1737198000,
#   'deadline_time_game_offset': 0,
#   'highest_score': 128,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': True,
#   'h2h_ko_matches_created': True,
#   'can_enter': False,
#   'can_manage': False,
#   'released': True,
#   'ranked_count': 11136058,
#   'overrides': {'rules': {},
#    'scoring': {},
#    'element_types': [],
#    'pick_multiplier': None},
#   'chip_plays': [{'chip_name': 'bboost', 'num_played': 102686},
#    {'chip_name': 'freehit', 'num_played': 35776},
#    {'chip_name': 'wildcard', 'num_played': 166215},
#    {'chip_name': '3xc', 'num_played': 45688}],
#   'most_selected': 328,
#   'most_transferred_in': 447,
#   'top_element': 71,
#   'top_element_info': {'id': 71, 'points': 22},
#   'transfers_made': 8284410,
#   'most_captained': 328,
#   'most_vice_captained': 182},
#  {'id': 23,
#   'name': 'Gameweek 23',
#   'deadline_time': '2025-01-25T13:30:00Z',
#   'release_time': None,
#   'average_entry_score': 59,
#   'finished': True,
#   'data_checked': True,
#   'highest_scoring_entry': 11007664,
#   'deadline_time_epoch': 1737811800,
#   'deadline_time_game_offset': 0,
#   'highest_score': 129,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': True,
#   'h2h_ko_matches_created': True,
#   'can_enter': False,
#   'can_manage': False,
#   'released': True,
#   'ranked_count': 11178740,
#   'overrides': {'rules': {},
#    'scoring': {},
#    'element_types': [],
#    'pick_multiplier': None},
#   'chip_plays': [{'chip_name': 'bboost', 'num_played': 125318},
#    {'chip_name': 'freehit', 'num_played': 41076},
#    {'chip_name': 'wildcard', 'num_played': 202189},
#    {'chip_name': '3xc', 'num_played': 145561}],
#   'most_selected': 328,
#   'most_transferred_in': 71,
#   'top_element': 74,
#   'top_element_info': {'id': 74, 'points': 21},
#   'transfers_made': 10475856,
#   'most_captained': 328,
#   'most_vice_captained': 401},
#  {'id': 24,
#   'name': 'Gameweek 24',
#   'deadline_time': '2025-02-01T11:00:00Z',
#   'release_time': None,
#   'average_entry_score': 87,
#   'finished': True,
#   'data_checked': True,
#   'highest_scoring_entry': 5428593,
#   'deadline_time_epoch': 1738407600,
#   'deadline_time_game_offset': 0,
#   'highest_score': 201,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': True,
#   'h2h_ko_matches_created': True,
#   'can_enter': False,
#   'can_manage': False,
#   'released': True,
#   'ranked_count': 11216322,
#   'overrides': {'rules': {},
#    'scoring': {},
#    'element_types': [],
#    'pick_multiplier': None},
#   'chip_plays': [{'chip_name': 'bboost', 'num_played': 111461},
#    {'chip_name': 'freehit', 'num_played': 123991},
#    {'chip_name': 'wildcard', 'num_played': 129674},
#    {'chip_name': '3xc', 'num_played': 1139007},
#    {'chip_name': 'manager', 'num_played': 1177726}],
#   'most_selected': 328,
#   'most_transferred_in': 321,
#   'top_element': 328,
#   'top_element_info': {'id': 328, 'points': 29},
#   'transfers_made': 11002861,
#   'most_captained': 328,
#   'most_vice_captained': 401},
#  {'id': 25,
#   'name': 'Gameweek 25',
#   'deadline_time': '2025-02-14T18:30:00Z',
#   'release_time': None,
#   'average_entry_score': 74,
#   'finished': True,
#   'data_checked': True,
#   'highest_scoring_entry': 2065637,
#   'deadline_time_epoch': 1739557800,
#   'deadline_time_game_offset': 0,
#   'highest_score': 155,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': True,
#   'h2h_ko_matches_created': True,
#   'can_enter': False,
#   'can_manage': False,
#   'released': True,
#   'ranked_count': 11262176,
#   'overrides': {'rules': {},
#    'scoring': {},
#    'element_types': [],
#    'pick_multiplier': None},
#   'chip_plays': [{'chip_name': 'bboost', 'num_played': 82673},
#    {'chip_name': 'freehit', 'num_played': 92674},
#    {'chip_name': 'wildcard', 'num_played': 127582},
#    {'chip_name': '3xc', 'num_played': 636104},
#    {'chip_name': 'manager', 'num_played': 901391}],
#   'most_selected': 328,
#   'most_transferred_in': 71,
#   'top_element': 328,
#   'top_element_info': {'id': 328, 'points': 20},
#   'transfers_made': 11066698,
#   'most_captained': 328,
#   'most_vice_captained': 182},
#  {'id': 26,
#   'name': 'Gameweek 26',
#   'deadline_time': '2025-02-21T18:30:00Z',
#   'release_time': None,
#   'average_entry_score': 62,
#   'finished': True,
#   'data_checked': True,
#   'highest_scoring_entry': 1546737,
#   'deadline_time_epoch': 1740162600,
#   'deadline_time_game_offset': 0,
#   'highest_score': 140,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': True,
#   'h2h_ko_matches_created': True,
#   'can_enter': False,
#   'can_manage': False,
#   'released': True,
#   'ranked_count': 11285417,
#   'overrides': {'rules': {},
#    'scoring': {},
#    'element_types': [],
#    'pick_multiplier': None},
#   'chip_plays': [{'chip_name': 'bboost', 'num_played': 54221},
#    {'chip_name': 'freehit', 'num_played': 28439},
#    {'chip_name': 'wildcard', 'num_played': 103756},
#    {'chip_name': '3xc', 'num_played': 18604},
#    {'chip_name': 'manager', 'num_played': 390248}],
#   'most_selected': 328,
#   'most_transferred_in': 71,
#   'top_element': 762,
#   'top_element_info': {'id': 762, 'points': 15},
#   'transfers_made': 8907059,
#   'most_captained': 328,
#   'most_vice_captained': 182},
#  {'id': 27,
#   'name': 'Gameweek 27',
#   'deadline_time': '2025-02-25T18:00:00Z',
#   'release_time': None,
#   'average_entry_score': 53,
#   'finished': True,
#   'data_checked': True,
#   'highest_scoring_entry': 10980207,
#   'deadline_time_epoch': 1740506400,
#   'deadline_time_game_offset': 0,
#   'highest_score': 120,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': True,
#   'h2h_ko_matches_created': True,
#   'can_enter': False,
#   'can_manage': False,
#   'released': True,
#   'ranked_count': 11301288,
#   'overrides': {'rules': {},
#    'scoring': {},
#    'element_types': [],
#    'pick_multiplier': None},
#   'chip_plays': [{'chip_name': 'bboost', 'num_played': 48902},
#    {'chip_name': 'freehit', 'num_played': 29345},
#    {'chip_name': 'wildcard', 'num_played': 104007},
#    {'chip_name': '3xc', 'num_played': 23870},
#    {'chip_name': 'manager', 'num_played': 352459}],
#   'most_selected': 328,
#   'most_transferred_in': 541,
#   'top_element': 163,
#   'top_element_info': {'id': 163, 'points': 15},
#   'transfers_made': 7849779,
#   'most_captained': 328,
#   'most_vice_captained': 182},
#  {'id': 28,
#   'name': 'Gameweek 28',
#   'deadline_time': '2025-03-08T11:00:00Z',
#   'release_time': None,
#   'average_entry_score': 52,
#   'finished': True,
#   'data_checked': True,
#   'highest_scoring_entry': 4865928,
#   'deadline_time_epoch': 1741431600,
#   'deadline_time_game_offset': 0,
#   'highest_score': 122,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': True,
#   'h2h_ko_matches_created': True,
#   'can_enter': False,
#   'can_manage': False,
#   'released': True,
#   'ranked_count': 11328678,
#   'overrides': {'rules': {},
#    'scoring': {},
#    'element_types': [],
#    'pick_multiplier': None},
#   'chip_plays': [{'chip_name': 'bboost', 'num_played': 71044},
#    {'chip_name': 'freehit', 'num_played': 35554},
#    {'chip_name': 'wildcard', 'num_played': 115172},
#    {'chip_name': '3xc', 'num_played': 154573},
#    {'chip_name': 'manager', 'num_played': 293173}],
#   'most_selected': 328,
#   'most_transferred_in': 211,
#   'top_element': 163,
#   'top_element_info': {'id': 163, 'points': 15},
#   'transfers_made': 8911975,
#   'most_captained': 328,
#   'most_vice_captained': 182},
#  {'id': 29,
#   'name': 'Gameweek 29',
#   'deadline_time': '2025-03-15T13:30:00Z',
#   'release_time': None,
#   'average_entry_score': 40,
#   'finished': True,
#   'data_checked': True,
#   'highest_scoring_entry': 885345,
#   'deadline_time_epoch': 1742045400,
#   'deadline_time_game_offset': 0,
#   'highest_score': 129,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': True,
#   'h2h_ko_matches_created': True,
#   'can_enter': False,
#   'can_manage': False,
#   'released': True,
#   'ranked_count': 11344621,
#   'overrides': {'rules': {},
#    'scoring': {},
#    'element_types': [],
#    'pick_multiplier': None},
#   'chip_plays': [{'chip_name': 'bboost', 'num_played': 14258},
#    {'chip_name': 'freehit', 'num_played': 1189224},
#    {'chip_name': 'wildcard', 'num_played': 221540},
#    {'chip_name': '3xc', 'num_played': 14819},
#    {'chip_name': 'manager', 'num_played': 105465}],
#   'most_selected': 328,
#   'most_transferred_in': 366,
#   'top_element': 366,
#   'top_element_info': {'id': 366, 'points': 17},
#   'transfers_made': 21126461,
#   'most_captained': 328,
#   'most_vice_captained': 182},
#  {'id': 30,
#   'name': 'Gameweek 30',
#   'deadline_time': '2025-04-01T17:15:00Z',
#   'release_time': None,
#   'average_entry_score': 44,
#   'finished': True,
#   'data_checked': True,
#   'highest_scoring_entry': 11409817,
#   'deadline_time_epoch': 1743527700,
#   'deadline_time_game_offset': 0,
#   'highest_score': 108,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': True,
#   'h2h_ko_matches_created': True,
#   'can_enter': False,
#   'can_manage': False,
#   'released': True,
#   'ranked_count': 11367765,
#   'overrides': {'rules': {},
#    'scoring': {},
#    'element_types': [],
#    'pick_multiplier': None},
#   'chip_plays': [{'chip_name': 'bboost', 'num_played': 70180},
#    {'chip_name': 'freehit', 'num_played': 33497},
#    {'chip_name': 'wildcard', 'num_played': 658984},
#    {'chip_name': '3xc', 'num_played': 32218},
#    {'chip_name': 'manager', 'num_played': 276833}],
#   'most_selected': 328,
#   'most_transferred_in': 755,
#   'top_element': 762,
#   'top_element_info': {'id': 762, 'points': 12},
#   'transfers_made': 15567710,
#   'most_captained': 328,
#   'most_vice_captained': 401},
#  {'id': 31,
#   'name': 'Gameweek 31',
#   'deadline_time': '2025-04-05T10:00:00Z',
#   'release_time': None,
#   'average_entry_score': 34,
#   'finished': True,
#   'data_checked': True,
#   'highest_scoring_entry': 2430340,
#   'deadline_time_epoch': 1743847200,
#   'deadline_time_game_offset': 0,
#   'highest_score': 109,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': True,
#   'h2h_ko_matches_created': True,
#   'can_enter': False,
#   'can_manage': False,
#   'released': True,
#   'ranked_count': 11373405,
#   'overrides': {'rules': {},
#    'scoring': {},
#    'element_types': [],
#    'pick_multiplier': None},
#   'chip_plays': [{'chip_name': 'bboost', 'num_played': 30471},
#    {'chip_name': 'freehit', 'num_played': 35898},
#    {'chip_name': 'wildcard', 'num_played': 476122},
#    {'chip_name': '3xc', 'num_played': 14043},
#    {'chip_name': 'manager', 'num_played': 275454}],
#   'most_selected': 328,
#   'most_transferred_in': 17,
#   'top_element': 491,
#   'top_element_info': {'id': 491, 'points': 18},
#   'transfers_made': 11309600,
#   'most_captained': 328,
#   'most_vice_captained': 401},
#  {'id': 32,
#   'name': 'Gameweek 32',
#   'deadline_time': '2025-04-12T10:00:00Z',
#   'release_time': None,
#   'average_entry_score': 56,
#   'finished': True,
#   'data_checked': True,
#   'highest_scoring_entry': 994851,
#   'deadline_time_epoch': 1744452000,
#   'deadline_time_game_offset': 0,
#   'highest_score': 168,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': True,
#   'h2h_ko_matches_created': True,
#   'can_enter': False,
#   'can_manage': False,
#   'released': True,
#   'ranked_count': 11382704,
#   'overrides': {'rules': {},
#    'scoring': {},
#    'element_types': [],
#    'pick_multiplier': None},
#   'chip_plays': [{'chip_name': 'bboost', 'num_played': 208952},
#    {'chip_name': 'freehit', 'num_played': 77639},
#    {'chip_name': 'wildcard', 'num_played': 279508},
#    {'chip_name': '3xc', 'num_played': 447125},
#    {'chip_name': 'manager', 'num_played': 286588}],
#   'most_selected': 328,
#   'most_transferred_in': 402,
#   'top_element': 392,
#   'top_element_info': {'id': 392, 'points': 27},
#   'transfers_made': 10134301,
#   'most_captained': 328,
#   'most_vice_captained': 328},
#  {'id': 33,
#   'name': 'Gameweek 33',
#   'deadline_time': '2025-04-19T12:30:00Z',
#   'release_time': None,
#   'average_entry_score': 56,
#   'finished': True,
#   'data_checked': True,
#   'highest_scoring_entry': 3094347,
#   'deadline_time_epoch': 1745065800,
#   'deadline_time_game_offset': 0,
#   'highest_score': 158,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': True,
#   'h2h_ko_matches_created': True,
#   'can_enter': False,
#   'can_manage': False,
#   'released': True,
#   'ranked_count': 11393467,
#   'overrides': {'rules': {},
#    'scoring': {},
#    'element_types': [],
#    'pick_multiplier': None},
#   'chip_plays': [{'chip_name': 'bboost', 'num_played': 766106},
#    {'chip_name': 'freehit', 'num_played': 293604},
#    {'chip_name': 'wildcard', 'num_played': 208909},
#    {'chip_name': '3xc', 'num_played': 281228},
#    {'chip_name': 'manager', 'num_played': 195973}],
#   'most_selected': 328,
#   'most_transferred_in': 17,
#   'top_element': 23,
#   'top_element_info': {'id': 23, 'points': 24},
#   'transfers_made': 12470167,
#   'most_captained': 328,
#   'most_vice_captained': 328},
#  {'id': 34,
#   'name': 'Gameweek 34',
#   'deadline_time': '2025-04-26T10:00:00Z',
#   'release_time': None,
#   'average_entry_score': 47,
#   'finished': True,
#   'data_checked': True,
#   'highest_scoring_entry': 2023246,
#   'deadline_time_epoch': 1745661600,
#   'deadline_time_game_offset': 0,
#   'highest_score': 132,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': True,
#   'h2h_ko_matches_created': True,
#   'can_enter': False,
#   'can_manage': False,
#   'released': True,
#   'ranked_count': 11403353,
#   'overrides': {'rules': {},
#    'scoring': {},
#    'element_types': [],
#    'pick_multiplier': None},
#   'chip_plays': [{'chip_name': 'bboost', 'num_played': 30585},
#    {'chip_name': 'freehit', 'num_played': 1061312},
#    {'chip_name': 'wildcard', 'num_played': 309768},
#    {'chip_name': '3xc', 'num_played': 75128},
#    {'chip_name': 'manager', 'num_played': 111707}],
#   'most_selected': 328,
#   'most_transferred_in': 541,
#   'top_element': 418,
#   'top_element_info': {'id': 418, 'points': 15},
#   'transfers_made': 23666358,
#   'most_captained': 328,
#   'most_vice_captained': 328},
#  {'id': 35,
#   'name': 'Gameweek 35',
#   'deadline_time': '2025-05-02T17:30:00Z',
#   'release_time': None,
#   'average_entry_score': 41,
#   'finished': True,
#   'data_checked': True,
#   'highest_scoring_entry': 2424807,
#   'deadline_time_epoch': 1746207000,
#   'deadline_time_game_offset': 0,
#   'highest_score': 105,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': True,
#   'h2h_ko_matches_created': True,
#   'can_enter': False,
#   'can_manage': False,
#   'released': True,
#   'ranked_count': 11411679,
#   'overrides': {'rules': {},
#    'scoring': {},
#    'element_types': [],
#    'pick_multiplier': None},
#   'chip_plays': [{'chip_name': 'bboost', 'num_played': 229389},
#    {'chip_name': 'freehit', 'num_played': 30320},
#    {'chip_name': 'wildcard', 'num_played': 152416},
#    {'chip_name': '3xc', 'num_played': 34402},
#    {'chip_name': 'manager', 'num_played': 197884}],
#   'most_selected': 328,
#   'most_transferred_in': 99,
#   'top_element': 106,
#   'top_element_info': {'id': 106, 'points': 14},
#   'transfers_made': 5993954,
#   'most_captained': 328,
#   'most_vice_captained': 328},
#  {'id': 36,
#   'name': 'Gameweek 36',
#   'deadline_time': '2025-05-10T12:30:00Z',
#   'release_time': None,
#   'average_entry_score': 43,
#   'finished': True,
#   'data_checked': True,
#   'highest_scoring_entry': 3950225,
#   'deadline_time_epoch': 1746880200,
#   'deadline_time_game_offset': 0,
#   'highest_score': 124,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': True,
#   'h2h_ko_matches_created': True,
#   'can_enter': False,
#   'can_manage': False,
#   'released': True,
#   'ranked_count': 11419348,
#   'overrides': {'rules': {},
#    'scoring': {},
#    'element_types': [],
#    'pick_multiplier': None},
#   'chip_plays': [{'chip_name': 'bboost', 'num_played': 408860},
#    {'chip_name': 'freehit', 'num_played': 76821},
#    {'chip_name': 'wildcard', 'num_played': 155193},
#    {'chip_name': '3xc', 'num_played': 184400},
#    {'chip_name': 'manager', 'num_played': 188132}],
#   'most_selected': 328,
#   'most_transferred_in': 345,
#   'top_element': 199,
#   'top_element_info': {'id': 199, 'points': 16},
#   'transfers_made': 8106582,
#   'most_captained': 328,
#   'most_vice_captained': 328},
#  {'id': 37,
#   'name': 'Gameweek 37',
#   'deadline_time': '2025-05-16T17:00:00Z',
#   'release_time': None,
#   'average_entry_score': 39,
#   'finished': True,
#   'data_checked': True,
#   'highest_scoring_entry': 8972552,
#   'deadline_time_epoch': 1747414800,
#   'deadline_time_game_offset': 0,
#   'highest_score': 115,
#   'is_previous': True,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': True,
#   'h2h_ko_matches_created': True,
#   'can_enter': False,
#   'can_manage': False,
#   'released': True,
#   'ranked_count': 11423894,
#   'overrides': {'rules': {},
#    'scoring': {},
#    'element_types': [],
#    'pick_multiplier': None},
#   'chip_plays': [{'chip_name': 'bboost', 'num_played': 369620},
#    {'chip_name': 'freehit', 'num_played': 66936},
#    {'chip_name': 'wildcard', 'num_played': 105773},
#    {'chip_name': '3xc', 'num_played': 135127},
#    {'chip_name': 'manager', 'num_played': 76895}],
#   'most_selected': 328,
#   'most_transferred_in': 58,
#   'top_element': 44,
#   'top_element_info': {'id': 44, 'points': 15},
#   'transfers_made': 5978738,
#   'most_captained': 328,
#   'most_vice_captained': 328},
#  {'id': 38,
#   'name': 'Gameweek 38',
#   'deadline_time': '2025-05-25T13:30:00Z',
#   'release_time': None,
#   'average_entry_score': 46,
#   'finished': True,
#   'data_checked': True,
#   'highest_scoring_entry': 949279,
#   'deadline_time_epoch': 1748179800,
#   'deadline_time_game_offset': 0,
#   'highest_score': 125,
#   'is_previous': False,
#   'is_current': True,
#   'is_next': False,
#   'cup_leagues_created': True,
#   'h2h_ko_matches_created': True,
#   'can_enter': False,
#   'can_manage': False,
#   'released': True,
#   'ranked_count': 11433257,
#   'overrides': {'rules': {},
#    'scoring': {},
#    'element_types': [],
#    'pick_multiplier': None},
#   'chip_plays': [{'chip_name': 'bboost', 'num_played': 682463},
#    {'chip_name': 'freehit', 'num_played': 146320},
#    {'chip_name': 'wildcard', 'num_played': 174276},
#    {'chip_name': '3xc', 'num_played': 326191},
#    {'chip_name': 'manager', 'num_played': 72580}],
#   'most_selected': 328,
#   'most_transferred_in': 617,
#   'top_element': 78,
#   'top_element_info': {'id': 78, 'points': 16},
#   'transfers_made': 9336077,
#   'most_captained': 328,
#   'most_vice_captained': 328}]

# %%
# see gameweek general info
r = requests.get('https://fantasy.premierleague.com/api/'+'bootstrap-static/').json()

# %%
r.keys()
# Out:
# dict_keys(['chips', 'events', 'game_settings', 'game_config', 'phases', 'teams', 'total_players', 'element_stats', 'element_types', 'elements'])

# %%
gw_info = r['events'][gw_no - 1]

# %%
gw_info # want this kind of info for our leagues especially chip plays, most_selected, most_captained
# Out:
# {'id': 38,
#  'name': 'Gameweek 38',
#  'deadline_time': '2025-05-25T13:30:00Z',
#  'release_time': None,
#  'average_entry_score': 46,
#  'finished': True,
#  'data_checked': True,
#  'highest_scoring_entry': 949279,
#  'deadline_time_epoch': 1748179800,
#  'deadline_time_game_offset': 0,
#  'highest_score': 125,
#  'is_previous': False,
#  'is_current': True,
#  'is_next': False,
#  'cup_leagues_created': True,
#  'h2h_ko_matches_created': True,
#  'can_enter': False,
#  'can_manage': False,
#  'released': True,
#  'ranked_count': 11433257,
#  'overrides': {'rules': {},
#   'scoring': {},
#   'element_types': [],
#   'pick_multiplier': None},
#  'chip_plays': [{'chip_name': 'bboost', 'num_played': 682463},
#   {'chip_name': 'freehit', 'num_played': 146320},
#   {'chip_name': 'wildcard', 'num_played': 174276},
#   {'chip_name': '3xc', 'num_played': 326191},
#   {'chip_name': 'manager', 'num_played': 72580}],
#  'most_selected': 328,
#  'most_transferred_in': 617,
#  'top_element': 78,
#  'top_element_info': {'id': 78, 'points': 16},
#  'transfers_made': 9336077,
#  'most_captained': 328,
#  'most_vice_captained': 328}

# %% [markdown]
# # Post match

# %%
assert get_gw_finished_status(gw_no)

# %%
league_name = 'rbsc'  #'rpk', 'ifc', 'rbsc'
league_id = get_league_id(league_name)

# %%
points = get_gw_points(league_id, gw_no)
points
# Out:
#     manager_id  gw_no  points  transfers_cost  h2h_points  rank
# 51     7729374     38      85               0          85     1
# 12     4105959     38      82               0          82     2
# 9      2271302     38      81               0          81     3
# 45     7344184     38      80               0          80     4
# 33     7620777     38      75               0          75     5
# 13     7348222     38      73               0          73     6
# 38      969423     38      72               0          72     7
# 39     5219630     38      73               4          69     8
# 0      1926920     38      69               0          69     8
# 48     2642311     38      73               4          69     8
# 23     4086852     38      68               0          68     9
# 26      732755     38      67               0          67    10
# 19     3680557     38      67               0          67    10
# 31     3878500     38      70               4          66    11
# 46     1015587     38      66               0          66    11
# 7      2890749     38      65               0          65    12
# 16     3481605     38      64               0          64    13
# 10     7300371     38      68               4          64    13
# 14     6740469     38      63               0          63    14
# 34     2780621     38      62               0          62    15
# 22     6031430     38      62               0          62    15
# 52     4944128     38      60               0          60    16
# 42     4172211     38      59               0          59    17
# 47     6634655     38      59               0          59    17
# 43     1831372     38      58               0          58    18
# 32     3256592     38      57               0          57    19
# 53     4087164     38      60               4          56    20
# 36     7307751     38      55               0          55    21
# 3      1972767     38      59               4          55    21
# 24     5242975     38      55               0          55    21
# 15     2549250     38      55               0          55    21
# 44     7258289     38      54               0          54    22
# 2        11333     38      54               0          54    22
# 4      4473266     38      53               0          53    23
# 27     7379063     38      60               8          52    24
# 54     7104076     38      56               4          52    24
# 28     4778474     38      51               0          51    25
# 21     1576908     38      50               0          50    26
# 5        27561     38      49               0          49    27
# 8       443013     38      49               0          49    27
# 25     5186410     38      49               0          49    27
# 35     3868570     38      48               0          48    28
# 1      2891449     38      50               4          46    29
# 18     6550939     38      45               0          45    30
# 11     1269606     38      47               4          43    31
# 6      4457564     38      44               4          40    32
# 41     2687717     38      40               0          40    32
# 17     4461199     38      47               8          39    33
# 40     1203040     38      42               4          38    34
# 20     3952331     38      38               0          38    34
# 29     3372221     38      38               0          38    34
# 30     4558829     38      36               0          36    35
# 37     4489759     38      33               0          33    36
# 49     7424891     38      33               0          33    36
# 50     6397351     38      33               0          33    36

# %%
pnl = get_gw_weekly_pnl(points, league_name)
pnl
# Out:
#    manager_id         team_name                         name  gw_no  points  \
# 3     7348222          Sirawatd             sirawat dulyavit     38      73
# 0     3611665         TachaponR        Tachapon Ratsameedara     38      69
# 6     5377619        PTHOMAS FC         PHOOM T. YENBAMROONG     38      66
# 2     2910243          Morty FC    Pattapong Charoenchaipong     38      60
# 4     1576908  Chicks Casino CF             Tawiwut Charuwat     38      50
# 7     3607641     OnkaewmaneeN.           Nithiz Onkaewmanee     38      48
# 5     4329910       proove.club  Natthawat Charoenkitmongkol     38      44
# 1     5961532            Aekk72             Atthapon Parkart     38      39
#
#    transfers_cost  h2h_points  rank  pnl  is_unique_rank
# 3               0          73     1  300            True
# 0               0          69     2  200            True
# 6               0          66     3  100            True
# 2               0          60     4    0            True
# 4               0          50     5    0            True
# 7               0          48     6 -100            True
# 5               0          44     7 -200            True
# 1               0          39     8 -300            True

# %%
try:
    # rpk only equal rank pnl hardcode
    if not pnl.is_unique_rank[0]:
        raise ValueError("Please hard code PNL")
except AttributeError:
    # not rpk and no is_unique_rank column
    pass

# %%
# pnl['pnl'] = [300,200,100,0,0,-100,-200,-300] # gw37
# assert pnl['pnl'].sum() == 0
# pnl

# %%
# text output for reporting
print(f'GW {gw_no} H2H results\n')

print('Top scorer(s):')
for index, row in pnl.iterrows():
    # มันเรียงมาตั้งแต่ Logic pnl
    if row['pnl'] > 0:
        print(f"{row['team_name']} ({row['name']}) {row['points']} - {row['transfers_cost']} = {row['h2h_points']} Pts [{row['pnl']}]\n")
    else:
        break

print('\nBottom(s) of the week:')    
for index, row in pnl.iterrows():
    # มันเรียงมาตั้งแต่ Logic pnl
    if row['pnl'] < 0:
        print(f"{row['team_name']} ({row['name']}) {row['points']} - {row['transfers_cost']} = {row['h2h_points']} Pts & [{row['pnl']}]\n")
# Out:
# GW 38 H2H results
#
# Top scorer(s):
# Sirawatd (sirawat dulyavit) 73 - 0 = 73 Pts [300]
#
# TachaponR (Tachapon Ratsameedara) 69 - 0 = 69 Pts [200]
#
# PTHOMAS FC (PHOOM T. YENBAMROONG) 66 - 0 = 66 Pts [100]
#
#
# Bottom(s) of the week:
# OnkaewmaneeN. (Nithiz Onkaewmanee) 48 - 0 = 48 Pts & [-100]
#
# proove.club (Natthawat Charoenkitmongkol) 44 - 0 = 44 Pts & [-200]
#
# Aekk72 (Atthapon Parkart) 39 - 0 = 39 Pts & [-300]

# %%
# write data into csv
# Specify the location and file name
file_location = f'data/2024-2025/fact_gw_{league_name}.csv'

# Write the DataFrame to a CSV file
# pnl.to_csv(file_location, index=False)

# Append the DataFrame to the existing CSV file
pnl.to_csv(file_location, mode='a', index=False, header=False)

# %% [markdown]
# # Pre match
# - Players data
# - Managers data
# - Managers picks
#     - captain selection
#     - most transfers
#     - selected by %

# %% [markdown]
# ## Player data

# %%
# get latest player data, fun data to look at
players = get_dim_players()

# %%
players.columns
# Out:
# Index(['chance_of_playing_next_round', 'chance_of_playing_this_round', 'code',
#        'cost_change_event', 'cost_change_event_fall', 'cost_change_start',
#        'cost_change_start_fall', 'dreamteam_count', 'element_type', 'ep_next',
#        'ep_this', 'event_points', 'first_name', 'form', 'id', 'in_dreamteam',
#        'news', 'news_added', 'now_cost', 'photo', 'points_per_game',
#        'second_name', 'selected_by_percent', 'special', 'squad_number',
#        'status', 'team', 'team_code', 'total_points', 'transfers_in',
#        'transfers_in_event', 'transfers_out', 'transfers_out_event',
#        'value_form', 'value_season', 'web_name', 'minutes', 'goals_scored',
#        'assists', 'clean_sheets', 'goals_conceded', 'own_goals',
#        'penalties_saved', 'penalties_missed', 'yellow_cards', 'red_cards',
#        'saves', 'bonus', 'bps', 'influence', 'creativity', 'threat',
#        'ict_index', 'starts', 'expected_goals', 'expected_assists',
#        'expected_goal_involvements', 'expected_goals_conceded',
#        'influence_rank', 'influence_rank_type', 'creativity_rank',
#        'creativity_rank_type', 'threat_rank', 'threat_rank_type',
#        'ict_index_rank', 'ict_index_rank_type',
#        'corners_and_indirect_freekicks_order',
#        'corners_and_indirect_freekicks_text', 'direct_freekicks_order',
#        'direct_freekicks_text', 'penalties_order', 'penalties_text',
#        'expected_goals_per_90', 'saves_per_90', 'expected_assists_per_90',
#        'expected_goal_involvements_per_90', 'expected_goals_conceded_per_90',
#        'goals_conceded_per_90', 'now_cost_rank', 'now_cost_rank_type',
#        'form_rank', 'form_rank_type', 'points_per_game_rank',
#        'points_per_game_rank_type', 'selected_rank', 'selected_rank_type',
#        'starts_per_90', 'clean_sheets_per_90'],
#       dtype='object')

# %%
players.loc[players.id == 9, ['first_name', 'second_name']]
# Out:
#   first_name       second_name
# 8    Gabriel  Martinelli Silva

# %% [markdown]
# ## Manager data

# %%
managers = get_dim_managers(league_id)

# %%
managers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 22 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   id                             55 non-null     int64
#  1   joined_time                    55 non-null     object
#  2   started_event                  55 non-null     int64
#  3   favourite_team                 52 non-null     float64
#  4   player_first_name              55 non-null     object
#  5   player_last_name               55 non-null     object
#  6   player_region_id               55 non-null     int64
#  7   player_region_name             55 non-null     object
#  8   player_region_iso_code_short   55 non-null     object
#  9   player_region_iso_code_long    55 non-null     object
#  10  years_active                   55 non-null     int64
#  11  summary_overall_points         55 non-null     int64
#  12  summary_overall_rank           55 non-null     int64
#  13  summary_event_points           55 non-null     int64
#  14  summary_event_rank             55 non-null     int64
#  15  current_event                  55 non-null     int64
#  16  name                           55 non-null     object
#  17  name_change_blocked            55 non-null     bool
#  18  entered_events                 55 non-null     object
#  19  last_deadline_bank             55 non-null     int64
#  20  last_deadline_value            55 non-null     int64
#  21  last_deadline_total_transfers  55 non-null     int64
# dtypes: bool(1), float64(1), int64(12), object(8)
# memory usage: 9.2+ KB

# %% [markdown]
# ## Manager picks

# %%
gw_picks = get_gw_picks(league_id, gw_no)

# %%
gw_picks
# Out:
#      element  position  multiplier  is_captain  is_vice_captain  manager_id
# 0         15         1           1       False            False     3481605
# 1         18         2           1       False            False     3481605
# 2        255         3           1       False            False     3481605
# 3        340         4           1       False            False     3481605
# 4        291         5           1       False            False     3481605
# ..       ...       ...         ...         ...              ...         ...
# 820      389        11           1       False            False     7104076
# 821      413        12           0       False            False     7104076
# 822      129        13           0       False            False     7104076
# 823      210        14           0       False            False     7104076
# 824      369        15           0       False            False     7104076
#
# [825 rows x 6 columns]

# %%
# join with other data for description
gw_picks = pd.merge(gw_picks, players, left_on='element', right_on='id') # get player names
gw_picks = pd.merge(gw_picks, managers, left_on='manager_id', right_on='id') # get manager names

# %% [markdown]
# ### Captains

# %%
captains = gw_picks.loc[gw_picks.is_captain == True]

# %%
# who captain who?
captains.loc[
    :,
    ['first_name', 'second_name', 'player_first_name', 'player_last_name', 'name']
    ].sort_values('first_name')
# Out:
#     first_name second_name player_first_name player_last_name  \
# 454     Bukayo        Saka             Cobby         Leathers
# 49      Bukayo        Saka               Tor        Na Ranong
# 667     Bukayo        Saka           sirawat         dulyavit
# 156     Bukayo        Saka           Tawiwut         Charuwat
# 472       Cole      Palmer             Teddy                T
# 400       Cole      Palmer              Sira                H
# 533       Cole      Palmer           Pimadej    Siwapornpitak
# 276       Cole      Palmer              Nick    Thanapoomikul
# 640       Cole      Palmer            Guitar       Raktakanit
# 233       Cole      Palmer          Sirichai     Jirapongphan
# 432       Cole      Palmer          Pannawit                M
# 679       Cole      Palmer          Wanwiwat        Thongproh
# 815       Cole      Palmer     Pradidthakorn          Kasiwat
# 786       Cole      Palmer            Samote      Viranuvatti
# 112       Cole      Palmer           Piyanut      Rattanapian
# 41        Cole      Palmer             Sarif           Sainui
# 695       Cole      Palmer         theerapat    phuaphanthong
# 705     Erling     Haaland            Lemony             Maaa
# 482     Erling     Haaland         Nopphanan      Vannapanich
# 498     Erling     Haaland              Akin    Suriyabhivadh
# 512     Erling     Haaland              BooM    Suriyabhivadh
# 765     Erling     Haaland             James             Rama
# 541     Erling     Haaland          Nopnarit       Lieopanich
# 586     Erling     Haaland             Kitti            Traii
# 750     Erling     Haaland            Ekapan              Ake
# 601     Erling     Haaland               Tae   Uahwatanasakul
# 735     Erling     Haaland              Palm               S.
# 720     Erling     Haaland        Natchanont       Kraitrakul
# 556     Erling     Haaland               Pow              …..
# 646     Erling     Haaland               gub      Na Songkhla
# 10      Erling     Haaland             Napin       Surakkhaka
# 795     Erling     Haaland          Bhuthong         Thongyai
# 18      Erling     Haaland               Tun    Suraphongchai
# 65      Erling     Haaland               New      Poshyananda
# 92      Erling     Haaland          sermwong             tcfc
# 121     Erling     Haaland               Gig         ONEPOINT
# 138     Erling     Haaland               Nab         Thavisin
# 167     Erling     Haaland             Smith    Mekaroonkamol
# 181     Erling     Haaland              Nile       Buranasiri
# 196     Erling     Haaland             Pravi        Techasith
# 436     Erling     Haaland          Sutthapa    Soonthornthum
# 242     Erling     Haaland              Peep        Chutrakul
# 257     Erling     Haaland             Garin        Settachan
# 302     Erling     Haaland               Roy           Chayut
# 317     Erling     Haaland             Kevin                V
# 333     Erling     Haaland             Arnon        Porndhiti
# 347     Erling     Haaland               Pum           Lamsam
# 364     Erling     Haaland              Pote                V
# 378     Erling     Haaland             Chuan             Krub
# 407     Erling     Haaland              Fung      Niamkongkit
# 85       Kevin   De Bruyne          songkram      chaimongkol
# 212    Mohamed       Salah              Tone        Na Ranong
# 286    Mohamed       Salah         Gampanath     Udomsorayuth
# 570    Mohamed       Salah             Richy        Very Much
# 615    Mohamed       Salah             Ayudh     phonghanyudh
#
#                      name
# 454             FC Cobbra
# 49                  TNR30
# 667              Sirawatd
# 156      Chicks Casino CF
# 472        Ted in the Box
# 400    Pending Moderation
# 533          Fame’s Squad
# 276                    NT
# 640              Guitar29
# 233              Timmy_AC
# 432             Sarr Wars
# 679       Customsanova FC
# 815           Little Team
# 786                Pun FC
# 112              Nut_RBAC
# 41                  SARIF
# 695                    Lb
# 705               lemonnn
# 482             Gapfrappe
# 498               Akin FC
# 512             69 United
# 765                   VO2
# 541               Toffees
# 586                   kcb
# 750                   3NA
# 601                Drogba
# 735               Palm S.
# 720         Heung Min Mon
# 556                   pow
# 646           de ligt est
# 10                 SNAPIN
# 795             Cool Hand
# 18              Raygun FC
# 65   What’s on the Mainoo
# 92                   TCFC
# 121              SuperGig
# 138       Lord of De Ligt
# 167            Winning XI
# 181                 BPong
# 196             PT United
# 436               Ikuko S
# 242                  peep
# 257            BoBoChaCha
# 302                CM7 FC
# 317         Obi Wan Iwobi
# 333                McFred
# 347        Slot into Diaz
# 364           Raging Bull
# 378       Chuan United ⚽️
# 407               Team 14
# 85            songkram fc
# 212          Tone's squad
# 286           ganpgampLFC
# 570              Richy FC
# 615             ayebypass

# %%
# summary
captained_by = captains.groupby(['element', 'first_name', 'second_name']).size().sort_values(ascending=False).reset_index(name='managers_captained_by')
captained_by['percent_captained_by'] = round(captained_by.managers_captained_by / managers.shape[0] * 100, 2)

# %%
captained_by
# Out:
#    element first_name second_name  managers_captained_by  percent_captained_by
# 0      351     Erling     Haaland                     33                 60.00
# 1      182       Cole      Palmer                     13                 23.64
# 2       17     Bukayo        Saka                      4                  7.27
# 3      328    Mohamed       Salah                      4                  7.27
# 4      345      Kevin   De Bruyne                      1                  1.82

# %% [markdown]
# ### most selected

# %%
selected_by = gw_picks[gw_picks.multiplier != 0].groupby(['element', 'first_name', 'second_name']).size().sort_values(ascending=False).reset_index(name='managers_selected_by')

# %%
selected_by['percent_selected_by'] = round(selected_by.managers_selected_by / managers.shape[0] * 100, 2)

# %%
selected_by.head(10)
# Out:
#    element first_name        second_name  managers_selected_by  \
# 0      351     Erling            Haaland                    43
# 1      401  Alexander               Isak                    34
# 2       17     Bukayo               Saka                    28
# 3       19      Emile         Smith Rowe                    26
# 4      350      Joško           Gvardiol                    24
# 5      328    Mohamed              Salah                    23
# 6      182       Cole             Palmer                    22
# 7      317      Diogo  Teixeira da Silva                    21
# 8      311      Trent   Alexander-Arnold                    19
# 9      255    Antonee           Robinson                    17
#
#    percent_selected_by
# 0                78.18
# 1                61.82
# 2                50.91
# 3                47.27
# 4                43.64
# 5                41.82
# 6                40.00
# 7                38.18
# 8                34.55
# 9                30.91

# %%
# have both Salah and Haaland?
gw_picks[gw_picks.element.isin([351,328])].groupby(['manager_id', 'player_first_name', 'player_last_name', 'name']).size().sort_values(ascending=False)
# Out:
# manager_id  player_first_name  player_last_name  name
# 6550939     Pow                …..               pow                     2
# 2891449     Akin               Suriyabhivadh     Akin FC                 2
# 6031430     Pum                Lamsam            Slot into Diaz          2
# 4457564     Chuan              Krub              Chuan United ⚽️         2
# 2271302     Pimadej            Siwapornpitak     Fame’s Squad            2
# 3481605     Napin              Surakkhaka        SNAPIN                  2
# 1831372     Wanwiwat           Thongproh         Customsanova FC         2
# 5186410     Gampanath          Udomsorayuth      ganpgampLFC             2
# 1203040     Samote             Viranuvatti       Pun FC                  2
# 969423      Fung               Niamkongkit       Team 14                 2
# 4473266     Tae                Uahwatanasakul    Drogba                  2
# 2890749     BooM               Suriyabhivadh     69 United               2
# 4778474     Sira               H                 4Ks 1st XI              1
# 5219630     sermwong           tcfc              TCFC                    1
# 4558829     Nick               Thanapoomikul     NT                      1
# 5242975     Ayudh              phonghanyudh      ayebypass               1
# 4489759     Sirichai           Jirapongphan      Timmy_AC                1
# 11333       Pannawit           M                 Sarr Wars               1
# 6397351     Nopphanan          Vannapanich       Gapfrappe               1
# 6634655     Tun                Suraphongchai     Raygun FC               1
# 6740469     Smith              Mekaroonkamol     Winning XI              1
# 7258289     Nab                Thavisin          Lord of De Ligt         1
# 7300371     Lemony             Maaa              lemonnn                 1
# 7348222     sirawat            dulyavit          Sirawatd                1
# 7379063     Sarif              Sainui            SARIF                   1
# 7424891     Bhuthong           Thongyai          Cool Hand               1
# 7620777     Teddy              T                 Ted in the Box          1
# 4461199     Richy              Very Much         Richy FC                1
# 3952331     Palm               S.                Palm S.                 1
# 4172211     Ekapan             Ake               3NA                     1
# 4105959     songkram           chaimongkol       songkram fc             1
# 443013      Natchanont         Kraitrakul        Heung Min Mon           1
# 732755      New                Poshyananda       What’s on the Mainoo    1
# 1015587     gub                Na Songkhla       de ligt est             1
# 1269606     Nile               Buranasiri        BPong                   1
# 1576908     Tawiwut            Charuwat          Chicks Casino CF        1
# 1926920     Roy                Chayut            CM7 FC                  1
# 1972767     Arnon              Porndhiti         McFred                  1
# 2549250     Tone               Na Ranong         Tone's squad            1
# 2687717     Garin              Settachan         BoBoChaCha              1
# 2780621     Peep               Chutrakul         peep                    1
# 3256592     James              Rama              VO2                     1
# 3372221     Kevin              V                 Obi Wan Iwobi           1
# 3680557     Nopnarit           Lieopanich        Toffees                 1
# 3868570     Pravi              Techasith         PT United               1
# 3878500     Guitar             Raktakanit        Guitar29                1
# 27561       Sutthapa           Soonthornthum     Ikuko S                 1
# 4086852     Pote               V                 Raging Bull             1
# 7729374     Cobby              Leathers          FC Cobbra               1
# dtype: int64

# %%
# Salah and Haaland
for manager_id in managers.id:
    gw_pick = get_manager_picks(manager_id, gw_no)['picks']
    pick_index = 0
    has_h = False
    has_s = False
    for pick in gw_pick:
        if pick['element'] == 351:
            has_h = True
        elif pick['element'] == 328:
            has_s = True
    if has_h and has_s:
        print(manager_id, has_h, has_s)
# Out:
# 5186410 True True
# 3481605 True True
# 2271302 True True
# 4457564 True True
# 6550939 True True
# 1203040 True True
# 1831372 True True
# 2891449 True True
# 4473266 True True
# 2890749 True True
# 969423 True True
# 6031430 True True

# %%
# Salah and Haaland
h_s = []
h_nos = []
noh_s = []
noh_nos = []
for manager_id in managers.id:
    gw_pick = get_manager_picks(manager_id, gw_no)['picks']
    pick_index = 0
    has_h = False
    has_s = False
    for pick in gw_pick:
        if pick['element'] == 351:
            has_h = True
        elif pick['element'] == 328:
            has_s = True
    if has_h and has_s:
        h_s.append(manager_id)
    elif has_h and not has_s:
        h_nos.append(manager_id)
    elif not has_h and has_s:
        noh_s.append(manager_id)
    else:
        noh_nos.append(manager_id)
print(len(h_s),len(h_nos),len(noh_s),len(noh_nos))
# Out:
# 12 27 10 5

# %%
noh_nos
# Out:
# [7307751, 7104076, 4944128, 4087164, 2642311]

# %%
# rpk only equal rank pnl hardcode
# points['pnl'] = []

# %% [markdown]
# ### Chips (work in progress)

# %%
for manager_id in managers.id:
    print(manager_id)
    print(type(manager_id))
# Out:
# 8264377
# <class 'int'>
# 8151266
# <class 'int'>
# 1576908
# <class 'int'>
# 1183765
# <class 'int'>
# 2893557
# <class 'int'>
# 6949233
# <class 'int'>
# 5908058
# <class 'int'>
# 3961683
# <class 'int'>
# 6301628
# <class 'int'>
# 779014
# <class 'int'>
# 3552329
# <class 'int'>
# 2968038
# <class 'int'>
# 6037486
# <class 'int'>
# 5337932
# <class 'int'>
# 5224099
# <class 'int'>
# 3613439
# <class 'int'>
# 8419308
# <class 'int'>
# 6669005
# <class 'int'>
# 6597853
# <class 'int'>

# %%
for manager_id in managers.id:
    active_chip = get_manager_picks(manager_id, gw_no)['active_chip']
    if active_chip:
        print(active_chip)
        print(managers.loc[managers.id == manager_id, ['player_first_name', 'player_last_name', 'name']])
# Out:
# wildcard
#   player_first_name player_last_name      name
# 3          Chotiwit   Jiratananuwong  Meatball
# wildcard
#   player_first_name player_last_name      name
# 5          Peerarat   Laolugsanalerd  peerarat

# %% [markdown]
# ### transfers

# %%
# TODO

# %% [markdown]
# # End of season

# %%
# df = pd.read_csv('./data/rbsc/fact_gw_rbsc.csv')
# for gw_no in range(37,38+1):
#     df = pd.concat([df, get_gw_weekly_pnl(get_gw_points(league_id, gw_no), league_name)], ignore_index=True)
#     gw_no += 1
